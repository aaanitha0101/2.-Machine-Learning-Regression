# %%
import pandas as pd

# %%
dataset=pd.read_csv("Insurance data.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first="True")

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={
    'kernel':['rbf','linear','poly','sigmoid'],
    'C':[10,100,1000],
}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid=grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
re=grid.cv_results_
print("Best model:{}".format(grid.best_params_))
# Out:
# Best model:{'C': 1000, 'kernel': 'linear'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        1.619894      0.578609         0.777446        0.274022      10
# 1        1.455470      0.721465         0.198478        0.100770      10
# 2        0.776091      0.057201         0.130872        0.007704      10
# 3        2.107199      0.111981         0.444262        0.118747      10
# 4        2.002005      0.065574         0.866896        0.134413     100
# 5        3.740324      0.293678         0.264286        0.027426     100
# 6        1.717840      0.143611         0.325349        0.090049     100
# 7        2.155925      0.014879         0.297634        0.013512     100
# 8        1.711546      0.142413         0.779106        0.066749    1000
# 9        9.540468      0.392728         0.166362        0.033445    1000
# 10       1.983258      0.121761         0.254780        0.020921    1000
# 11       1.667143      0.081140         0.246322        0.107265    1000
#
#    param_kernel                            params  split0_test_score  \
# 0           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 1        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 2          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 3       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 4           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 5        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 6          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 7       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 8           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 9        linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 10         poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 11      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.097459          -0.074488          -0.099597
# 1            0.029886           0.022167           0.003112
# 2           -0.081505          -0.111907          -0.131602
# 3           -0.119312          -0.085214          -0.108210
# 4           -0.107253          -0.123430          -0.137753
# 5            0.521798           0.547691           0.538805
# 6           -0.082461          -0.129220          -0.139962
# 7           -0.160831          -0.117544          -0.137984
# 8           -0.098267          -0.123724          -0.137137
# 9            0.675162           0.680002           0.699377
# 10          -0.028469          -0.073376          -0.086611
# 11          -2.686121          -2.194563          -2.210858
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.124428        -0.101276        0.016459                5
# 1           -0.066653        -0.006086        0.034672                3
# 2           -0.179328        -0.125899        0.031794                7
# 3           -0.108716        -0.107639        0.012029                6
# 4           -0.209551        -0.147634        0.035511               11
# 5            0.508518         0.535225        0.018122                2
# 6           -0.189219        -0.134749        0.033948                8
# 7           -0.130402        -0.137843        0.014263                9
# 8           -0.206405        -0.144193        0.036262               10
# 9            0.677952         0.693778        0.022955                1
# 10          -0.134493        -0.080695        0.033795                4
# 11          -1.942521        -2.215441        0.255409               12

# %%
Future_Prediction=grid.predict([[18,33.770,1,1,0]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction
# Out:
# array([1341.1445423])
