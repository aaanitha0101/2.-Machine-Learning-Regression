# %%
import pandas as pd

# %%
dataset=pd.read_csv("Insurance data.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first="True")

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={
    'criterion':['squared_error','absolute_error','poisson','friedman_mse'],
    'splitter':['best','random']
}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid=grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits

# %%
re=grid.cv_results_
print("Best model:{}".format(grid.best_params_))
# Out:
# Best model:{'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.016246      0.008449         0.007839        0.004169
# 1       0.008459      0.002484         0.003642        0.002235
# 2       0.056810      0.010571         0.004670        0.002337
# 3       0.059324      0.015233         0.004872        0.000849
# 4       0.030905      0.008484         0.004975        0.001192
# 5       0.011803      0.004619         0.006392        0.002939
# 6       0.018354      0.008531         0.008956        0.005013
# 7       0.012575      0.003947         0.005654        0.000605
#
#   param_criterion param_splitter  \
# 0   squared_error           best
# 1   squared_error         random
# 2  absolute_error           best
# 3  absolute_error         random
# 4         poisson           best
# 5         poisson         random
# 6    friedman_mse           best
# 7    friedman_mse         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'splitter': 'be...           0.724075
# 1  {'criterion': 'squared_error', 'splitter': 'ra...           0.675995
# 2  {'criterion': 'absolute_error', 'splitter': 'b...           0.705137
# 3  {'criterion': 'absolute_error', 'splitter': 'r...           0.742770
# 4       {'criterion': 'poisson', 'splitter': 'best'}           0.708597
# 5     {'criterion': 'poisson', 'splitter': 'random'}           0.630953
# 6  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.731950
# 7  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.648406
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.657370           0.734297           0.726162           0.671417
# 1           0.677917           0.696069           0.699887           0.745691
# 2           0.611693           0.704619           0.715620           0.750215
# 3           0.604796           0.793030           0.637748           0.719416
# 4           0.624919           0.716450           0.736226           0.669616
# 5           0.555894           0.656509           0.613173           0.740455
# 6           0.651772           0.738267           0.710680           0.682279
# 7           0.582063           0.669679           0.676827           0.743228
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.702664        0.031747                2
# 1         0.699111        0.025152                4
# 2         0.697457        0.045998                5
# 3         0.699552        0.068991                3
# 4         0.691162        0.039564                6
# 5         0.639397        0.060394                8
# 6         0.702989        0.032232                1
# 7         0.664041        0.051828                7

# %%
Future_Prediction=grid.predict([[18,33.770,1,1,0]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction
# Out:
# array([1725.5523])
