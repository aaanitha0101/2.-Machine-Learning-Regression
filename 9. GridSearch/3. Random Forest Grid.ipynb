# %%
import pandas as pd

# %%
dataset=pd.read_csv("Insurance data.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first="True")

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={
    'criterion':['squared_error','absolute_error','poisson','friedman_mse'],
    'n_estimators':[100,50]
}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid=grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
re=grid.cv_results_
print("Best model:{}".format(grid.best_params_))
# Out:
# Best model:{'criterion': 'squared_error', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       7.022268      0.690585         0.330372        0.064153
# 1       2.265147      1.096651         0.129726        0.088699
# 2      19.479441      7.526732         0.104756        0.062355
# 3      12.045028      2.658597         0.143010        0.065138
# 4       7.536603      1.879186         0.253528        0.115321
# 5       4.290152      0.262729         0.143258        0.011025
# 6       4.040766      1.588109         0.192864        0.150504
# 7       2.370610      0.690566         0.162679        0.073584
#
#   param_criterion param_n_estimators  \
# 0   squared_error                100
# 1   squared_error                 50
# 2  absolute_error                100
# 3  absolute_error                 50
# 4         poisson                100
# 5         poisson                 50
# 6    friedman_mse                100
# 7    friedman_mse                 50
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'n_estimators':...           0.849039
# 1  {'criterion': 'squared_error', 'n_estimators':...           0.846718
# 2  {'criterion': 'absolute_error', 'n_estimators'...           0.835475
# 3  {'criterion': 'absolute_error', 'n_estimators'...           0.838384
# 4      {'criterion': 'poisson', 'n_estimators': 100}           0.817081
# 5       {'criterion': 'poisson', 'n_estimators': 50}           0.809403
# 6  {'criterion': 'friedman_mse', 'n_estimators': ...           0.849102
# 7  {'criterion': 'friedman_mse', 'n_estimators': 50}           0.845589
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.769475           0.855632           0.821565           0.835895
# 1           0.764865           0.858799           0.815075           0.837057
# 2           0.768069           0.851275           0.826238           0.835080
# 3           0.763734           0.849260           0.825149           0.831038
# 4           0.746640           0.824190           0.827955           0.802973
# 5           0.760876           0.822925           0.826106           0.798445
# 6           0.766746           0.857665           0.819078           0.834959
# 7           0.771982           0.859070           0.814263           0.836046
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.826321        0.030728                1
# 1         0.824503        0.033084                4
# 2         0.823227        0.028736                5
# 3         0.821513        0.029990                6
# 4         0.803768        0.029811                7
# 5         0.803551        0.023518                8
# 6         0.825510        0.032170                2
# 7         0.825390        0.030437                3

# %%
Future_Prediction=grid.predict([[18,33.770,1,1,0]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction
# Out:
# array([2452.4553545])
